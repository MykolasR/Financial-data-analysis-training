# %%
#modify dataframes ans useful functions

import pandas as pd

data=pd.read_csv("C:/Users/Vartotojas/Desktop/Financial analysis training/AAPL.csv", index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-10-11  142.270004  144.809998  141.809998  142.809998  142.014206
# 2021-10-12  143.229996  143.250000  141.039993  141.509995  140.721451
# 2021-10-13  141.240005  141.399994  139.199997  140.910004  140.124786
# 2021-10-14  142.110001  143.880005  141.509995  143.759995  142.958923
# 2021-10-15  143.770004  144.899994  143.509995  144.839996  144.032898
#
#               Volume
# Date
# 2021-10-11  64452200
# 2021-10-12  73035900
# 2021-10-13  78762700
# 2021-10-14  69907100
# 2021-10-15  67940300

# %%
#insert additional column

data["Daily chg"] = data["Close"] - data["Open"]

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-10-11  142.270004  144.809998  141.809998  142.809998  142.014206
# 2021-10-12  143.229996  143.250000  141.039993  141.509995  140.721451
# 2021-10-13  141.240005  141.399994  139.199997  140.910004  140.124786
# 2021-10-14  142.110001  143.880005  141.509995  143.759995  142.958923
# 2021-10-15  143.770004  144.899994  143.509995  144.839996  144.032898
#
#               Volume  Daily chg
# Date
# 2021-10-11  64452200   0.539994
# 2021-10-12  73035900  -1.720001
# 2021-10-13  78762700  -0.330001
# 2021-10-14  69907100   1.649994
# 2021-10-15  67940300   1.069992

# %%
# calculation of growth
data["Normalized"] = data["Close"]/data["Close"].iloc[0]
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-10-11  142.270004  144.809998  141.809998  142.809998  142.014206
# 2021-10-12  143.229996  143.250000  141.039993  141.509995  140.721451
# 2021-10-13  141.240005  141.399994  139.199997  140.910004  140.124786
# 2021-10-14  142.110001  143.880005  141.509995  143.759995  142.958923
# 2021-10-15  143.770004  144.899994  143.509995  144.839996  144.032898
#
#               Volume  Daily chg  Normalized
# Date
# 2021-10-11  64452200   0.539994    1.000000
# 2021-10-12  73035900  -1.720001    0.990897
# 2021-10-13  78762700  -0.330001    0.986696
# 2021-10-14  69907100   1.649994    1.006652
# 2021-10-15  67940300   1.069992    1.014215

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  146.100006
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.399994
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.429993
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  140.089996
# 2022-10-10  140.419998  141.889999  138.570007  140.419998  140.419998
#
#               Volume  Daily chg  Normalized
# Date
# 2022-10-04  87830100   1.070007    1.023038
# 2022-10-05  79471000   2.329987    1.025138
# 2022-10-06  68402200  -0.380005    1.018346
# 2022-10-07  85859100  -2.449997    0.980954
# 2022-10-10  74827900   0.000000    0.983264

# %%
#find minimum value
data["Daily chg"].min()
# Out:
# -7.0800020000000075

# %%
#argmin function show the line numer which is the lowest
data["Close"].argmin()
# Out:
# 172

# %%
data.iloc[172]
# Out:
# Open          1.320800e+02
# High          1.323900e+02
# Low           1.290400e+02
# Close         1.300600e+02
# Adj Close     1.298796e+02
# Volume        1.081239e+08
# Daily chg    -2.020004e+00
# Normalized    9.107205e-01
# Name: 2022-06-16 00:00:00, dtype: float64

# %%
data["Close"].min()
# Out:
# 130.059998

# %%
data["Normalized"].min()
# Out:
# 0.9107205365271415

# %%
data["Normalized"].max()
# Out:
# 1.2744905647292286

# %%
data.iloc[250:]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  140.089996
# 2022-10-10  140.419998  141.889999  138.570007  140.419998  140.419998
#
#               Volume  Daily chg  Normalized
# Date
# 2022-10-07  85859100  -2.449997    0.980954
# 2022-10-10  74827900   0.000000    0.983264

# %%
# calculation of the mean (In this case not useful)
data["Close"].mean()
# Out:
# 158.6681351388889

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-10-11  142.270004  144.809998  141.809998  142.809998  142.014206
# 2021-10-12  143.229996  143.250000  141.039993  141.509995  140.721451
# 2021-10-13  141.240005  141.399994  139.199997  140.910004  140.124786
# 2021-10-14  142.110001  143.880005  141.509995  143.759995  142.958923
# 2021-10-15  143.770004  144.899994  143.509995  144.839996  144.032898
#
#               Volume  Daily chg  Normalized
# Date
# 2021-10-11  64452200   0.539994    1.000000
# 2021-10-12  73035900  -1.720001    0.990897
# 2021-10-13  78762700  -0.330001    0.986696
# 2021-10-14  69907100   1.649994    1.006652
# 2021-10-15  67940300   1.069992    1.014215

# %%
#delete columns. axis = 1 to delete columns not rows

data.drop(labels=["High", "Low", "Volume"], axis = 1, inplace=True)

#after inplace it changed dataframe and mentioned columns not found any more
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 #delete columns. axis = 1 to delete columns not rows
# ----> 3 data.drop(labels=["High", "Low", "Volume"], axis = 1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
# ...

# %%
data.head()
# Out:
#                   Open       Close   Adj Close  Daily chg  Normalized
# Date
# 2021-10-11  142.270004  142.809998  142.014206   0.539994    1.000000
# 2021-10-12  143.229996  141.509995  140.721451  -1.720001    0.990897
# 2021-10-13  141.240005  140.910004  140.124786  -0.330001    0.986696
# 2021-10-14  142.110001  143.759995  142.958923   1.649994    1.006652
# 2021-10-15  143.770004  144.839996  144.032898   1.069992    1.014215
